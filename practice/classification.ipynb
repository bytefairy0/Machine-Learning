# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df['species'] = iris.target

# %%
x = iris_df.drop('species', axis=1, inplace=False)
x
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
y = iris_df['species']
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 150, dtype: int64

# %%
# plot data
# data distribution 
plt.figure(figsize=(10, 8))
for i, col in enumerate(x.columns, 1):
    plt.subplot(2, 2, i)
    sns.histplot(iris_df[col], kde=True)
    plt.title("Distribution of {col}")
plt.tight_layout()
plt.show()

# %%
# target distribution
sns.countplot(x='species', data=iris_df, color='plum')
plt.title("Target distribution")
plt.show()

# %%
# heat map
plt.figure(figsize=(10, 8))
corr_matrix = iris_df.select_dtypes(include=np.number).corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', annot_kws={'size':10})
plt.title("Correlation Matrix")
plt.show()

# %%
# split dataset
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, shuffle=True)

# %%
# standardize data
scalar = StandardScaler()
x_train = scalar.fit_transform(x_train)
x_test = scalar.transform(x_test)

# %%
#fit knn model
knn_model = KNeighborsClassifier()
knn_model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn_model.predict(x_test)
y_pred
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0])

# %%
# test accuracy 
print(f"Test set accuracy {knn_model.score(x_test, y_test)*100:.2f}")
# Out:
# Test set accuracy 100.00

# %%
# confusion matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm, display_labels=iris_df['species'].unique())
disp.plot(cmap='Greens')
plt.plot("Confusion Matrix: KNN model")
plt.show()

# %% [markdown]
# ## Logistic regression

# %%
lr_model = LogisticRegression()
lr_model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr_model.predict(x_test)

# %%
iris_df['species'].unique()
# Out:
# array([0, 1, 2])

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm, display_labels=iris_df['species'].unique())
disp.plot(cmap='Blues')
plt.title("Confusion Matrix: Logistic Regression")
plt.show()
